# %%
import pandas as pd
import numpy as np
import sklearn as sklern
import seaborn as sb
import requests
from bs4 import BeautifulSoup
import urllib2
import matplotlib

# %%
premium = 200

# %%
print(premium)
# Out:
# 200

# %%
for x in range(1,3):
    print("Values of x %d" %(x))
# Out:
# Values of x 1
# Values of x 2

# %%
x = 1
while True:
    print("Values of X %d" (x))
    x+=1

# %%
print('{0} and {1}'.format('spam','test'))
# Out:
# spam and test

# %%
def hello():
    firstname = str(input("Enter your name: "))
    if len(firstname) > 1:
        print ("Hello " + str(firstname))
    else:
        print("Hello World") 
    return

# %%
url = "http://www.thairsc.com/th/BigAccDetail.aspx?qid=47142&l=th"
contentAccident = urllib2.urlopen(url).read()
soup = BeautifulSoup(content)
print soup.prettify()
print title
print soup.p
print soup.a
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    Pythonforbeginners.com - Learn Python by Example
#   </title>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://www.pythonforbeginners.com/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="website" property="og:type"/>
#   <meta content=" Pythonforbeginners.com - Learn Python by Example " property="og:title"/>
#   <meta content="https://www.pythonforbeginners.com/" property="og:url"/>
#   <meta content="Python For Beginners" property="og:site_name"/>
#   <link href="https://www.pythonforbeginners.com/feed/" rel="alternate" title="Python For Beginners » Feed" type="application/rss+xml"/>
# ...
